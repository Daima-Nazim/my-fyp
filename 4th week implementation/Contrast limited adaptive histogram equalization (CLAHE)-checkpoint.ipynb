# %%
import cv2
from skimage import io
from matplotlib import pyplot as plt

# %%
img = cv2.imread("20_right.jpeg", 1)

# %%
lab_img= cv2.cvtColor(img, cv2.COLOR_BGR2LAB)

# %%
l, a, b = cv2.split(lab_img)

# %%
plt.hist(l.flat, bins=100, range=(0,255))
# Out:
# (array([8.6150e+04, 1.1457e+04, 5.2570e+03, 7.6150e+03, 2.7710e+03,
#         9.5000e+02, 4.9500e+02, 4.7200e+02, 1.7000e+02, 3.8600e+02,
#         4.9100e+02, 1.5200e+02, 3.9200e+02, 1.4200e+02, 4.2800e+02,
#         2.2100e+02, 3.3300e+02, 2.2500e+02, 4.2800e+02, 1.5700e+02,
#         4.7800e+02, 5.4800e+02, 4.2800e+02, 1.0090e+03, 1.1850e+03,
#         3.3640e+03, 2.4330e+03, 5.0560e+03, 4.2940e+03, 7.4580e+03,
#         9.8590e+03, 7.5600e+03, 1.6028e+04, 1.4561e+04, 2.6427e+04,
#         2.0309e+04, 3.4567e+04, 2.6475e+04, 3.7214e+04, 2.2352e+04,
#         3.4269e+04, 3.0690e+04, 2.0675e+04, 2.9181e+04, 1.9012e+04,
#         2.7435e+04, 1.7228e+04, 2.3515e+04, 1.4752e+04, 1.9599e+04,
#         1.9197e+04, 1.1971e+04, 1.6574e+04, 1.0168e+04, 1.5777e+04,
#         1.0857e+04, 1.7150e+04, 1.2311e+04, 1.9625e+04, 1.4085e+04,
#         2.0130e+04, 1.7671e+04, 8.2630e+03, 8.0420e+03, 3.6480e+03,
#         3.9360e+03, 1.8970e+03, 1.9920e+03, 9.2300e+02, 1.3610e+03,
#         1.1440e+03, 6.4500e+02, 9.0000e+02, 5.3700e+02, 8.2500e+02,
#         4.7600e+02, 6.4400e+02, 3.4400e+02, 5.9500e+02, 4.0200e+02,
#         7.7400e+02, 1.3100e+03, 1.1160e+03, 1.3230e+03, 4.4200e+02,
#         5.8600e+02, 3.9100e+02, 4.3200e+02, 4.6400e+02, 8.0700e+02,
#         7.2500e+02, 6.5300e+02, 1.3400e+03, 8.4400e+02, 1.2480e+03,
#         2.4200e+02, 4.8000e+01, 0.0000e+00, 0.0000e+00, 0.0000e+00]),
#  array([  0.  ,   2.55,   5.1 ,   7.65,  10.2 ,  12.75,  15.3 ,  17.85,
#          20.4 ,  22.95,  25.5 ,  28.05,  30.6 ,  33.15,  35.7 ,  38.25,
#          40.8 ,  43.35,  45.9 ,  48.45,  51.  ,  53.55,  56.1 ,  58.65,
#          61.2 ,  63.75,  66.3 ,  68.85,  71.4 ,  73.95,  76.5 ,  79.05,
#          81.6 ,  84.15,  86.7 ,  89.25,  91.8 ,  94.35,  96.9 ,  99.45,
#         102.  , 104.55, 107.1 , 109.65, 112.2 , 114.75, 117.3 , 119.85,
#         122.4 , 124.95, 127.5 , 130.05, 132.6 , 135.15, 137.7 , 140.25,
#         142.8 , 145.35, 147.9 , 150.45, 153.  , 155.55, 158.1 , 160.65,
#         163.2 , 165.75, 168.3 , 170.85, 173.4 , 175.95, 178.5 , 181.05,
#         183.6 , 186.15, 188.7 , 191.25, 193.8 , 196.35, 198.9 , 201.45,
#         204.  , 206.55, 209.1 , 211.65, 214.2 , 216.75, 219.3 , 221.85,
#         224.4 , 226.95, 229.5 , 232.05, 234.6 , 237.15, 239.7 , 242.25,
#         244.8 , 247.35, 249.9 , 252.45, 255.  ]),
#  <BarContainer object of 100 artists>)

# %%
equ = cv2.equalizeHist(l)

# %%
updated_lab_img1 = cv2.merge((equ,a,b))

# %%
hist_eq_img = cv2.cvtColor(updated_lab_img1, cv2.COLOR_LAB2BGR)

# %%
clahe = cv2.createCLAHE(clipLimit=3.0, tileGridSize=(8,8))
clahe_img = clahe.apply(l)

# %%
updated_lab_img2 = cv2.merge((clahe_img,a,b))

# %%
CLAHE_img = cv2.cvtColor(updated_lab_img2, cv2.COLOR_LAB2BGR)

# %%
f = plt.figure(figsize=(15,15))
f.add_subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(updated_lab_img1, cv2.COLOR_LAB2BGR))
plt.title("Equalized image")

f.add_subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(updated_lab_img2, cv2.COLOR_LAB2BGR))
plt.title("CLAHE Image")

cv2.waitKey(0)
cv2.destroyAllWindows()
